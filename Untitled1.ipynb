# %%
import sys,os
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-7ed87fec2c83> in <module>()
#       4 import matplotlib
#       5 import matplotlib.pyplot as plt
# ----> 6 import seaborn as sns
#       7 get_ipython().magic(u'matplotlib inline')
#
# ImportError: No module named seaborn

# %%
d_crime=pd.read_csv('lapolicedata.csv')
print d_crime.shape
d_crime.head(1)
# Out:
# (65499, 9)
#                      DATE  TIME OCC     AREA                      Crime  \
# 0  12/02/2015 12:00:00 AM       150  Central  OTHER MISCELLANEOUS CRIME
#
#   Status  Status Desc                                  LOCATION Cross Street  \
# 0     IC  Invest Cont    400 S  LOS ANGELES                  ST          NaN
#
#              Location 1
# 0  (34.0473, -118.2462)

# %%
date=pd.to_datetime(d_crime['DATE'])
print date.min()
print date.max()
t_delta=(date-date.min()).astype('timedelta64[D]')
d_crime['days']=t_delta
d_crime.head(1)
# Out:
# 2015-08-24 00:00:00
# 2015-12-02 00:00:00
#                      DATE  TIME OCC     AREA                      Crime  \
# 0  12/02/2015 12:00:00 AM       150  Central  OTHER MISCELLANEOUS CRIME
#
#   Status  Status Desc                                  LOCATION Cross Street  \
# 0     IC  Invest Cont    400 S  LOS ANGELES                  ST          NaN
#
#              Location 1  days
# 0  (34.0473, -118.2462)   100

# %%
def plotdat(data,cat):
    l=data.groupby(cat).size()
    l.sort()
    fig=plt.figure(figsize=(10,5))
    plt.yticks(fontsize=8)
    l.plot(kind='bar',fontsize=12,color='k')
    plt.xlabel('')
    plt.ylabel('Number of reports',fontsize=10)

plotdat(d_crime,'Crime')

# %%
l=d_crime.groupby('Crime').size()
l.sort()
print l.shape
# Out:
# (126,)

# %%
def types_districts(d_crime,per):
    
    # Group by crime type and district 
    hoods_per_type=d_crime.groupby('Crime').Area.value_counts(sort=True)
    t=hoods_per_type.unstack().fillna(0)
    
    # Sort by hood sum
    hood_sum=t.sum(axis=0)
    hood_sum.sort(ascending=False)
    t=t[hood_sum.index]
    
    # Filter by crime per district
    crime_sum=t.sum(axis=1)
    crime_sum.sort()
    
    # Large number, so let's slice the data.
    p=np.percentile(crime_sum,per)
    ix=crime_sum[crime_sum>p]
    t=t.loc[ix.index]
    return t
    
t=types_districts(d_crime,96)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-dc277a71177c> in <module>()
#      20     return t
#      21
# ---> 22 t=types_districts(d_crime,96)
#
# <ipython-input-6-dc277a71177c> in types_districts(d_crime, per)
#       2
#       3     # Group by crime type and district
# ----> 4     hoods_per_type=d_crime.groupby('Crime').Area.value_counts(sort=True)
#       5     t=hoods_per_type.unstack().fillna(0)
#       6
#
# /Users/jmolayem/anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in __getattr__(self, attr)
#     518
#     519         raise AttributeError("%r object has no attribute %r" %
# --> 520                              (type(self).__name__, attr))
#     521
#     522     def __getitem__(self, key):
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'Area'

# %%
def types_districts(d_crime,per):
    
    # Group by crime type and district 
    hoods_per_type=d_crime.groupby('Crime').Area.value_counts(sort=True)
    t=hoods_per_type.unstack().fillna(0)
    
    # Sort by hood sum
    hood_sum=t.sum(axis=0)
    hood_sum.sort(ascending=False)
    t=t[hood_sum.index]
    
    # Filter by crime per district
    crime_sum=t.sum(axis=1)
    crime_sum.sort()
    
    # Large number, so let's slice the data.
    p=np.percentile(crime_sum,per)
    ix=crime_sum[crime_sum>p]
    t=t.loc[ix.index]
    return t
    
t=types_districts(d_crime,96)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-dc277a71177c> in <module>()
#      20     return t
#      21
# ---> 22 t=types_districts(d_crime,96)
#
# <ipython-input-7-dc277a71177c> in types_districts(d_crime, per)
#       2
#       3     # Group by crime type and district
# ----> 4     hoods_per_type=d_crime.groupby('Crime').Area.value_counts(sort=True)
#       5     t=hoods_per_type.unstack().fillna(0)
#       6
#
# /Users/jmolayem/anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in __getattr__(self, attr)
#     518
#     519         raise AttributeError("%r object has no attribute %r" %
# --> 520                              (type(self).__name__, attr))
#     521
#     522     def __getitem__(self, key):
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'Area'

# %%
def types_districts(d_crime,per):
    
    # Group by crime type and district 
    hoods_per_type=d_crime.groupby('Crime').Status.value_counts(sort=True)
    t=hoods_per_type.unstack().fillna(0)
    
    # Sort by hood sum
    hood_sum=t.sum(axis=0)
    hood_sum.sort(ascending=False)
    t=t[hood_sum.index]
    
    # Filter by crime per district
    crime_sum=t.sum(axis=1)
    crime_sum.sort()
    
    # Large number, so let's slice the data.
    p=np.percentile(crime_sum,per)
    ix=crime_sum[crime_sum>p]
    t=t.loc[ix.index]
    return t
    
t=types_districts(d_crime,96)

# %%
plotdat(d_crime,'Crime')

# %%
sns.clustermap(t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-f63df14a15dc> in <module>()
# ----> 1 sns.clustermap(t)
#
# NameError: name 'sns' is not defined

# %%
sns.clustermap(t,standard_scale=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-80e1266676f5> in <module>()
# ----> 1 sns.clustermap(t,standard_scale=0)
#
# NameError: name 'sns' is not defined

# %%
import seaborn as sb
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-13-d4acb16d6e9c> in <module>()
# ----> 1 import seaborn as sb
#
# ImportError: No module named seaborn

# %%
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-14-ed9806ce3570> in <module>()
# ----> 1 import seaborn as sns
#
# ImportError: No module named seaborn

# %%
import seaborn as sns
# Out:
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %%
sns.clustermap(t,standard_scale=0)

# %%
def plotdat(data,cat):
    l=data.groupby(cat).size()
    l.sort()
    fig=plt.figure(figsize=(10,5))
    plt.yticks(fontsize=8)
    l.plot(kind='bar',fontsize=12,color='k')
    plt.xlabel('')
    plt.ylabel('Number of reports',fontsize=10)

plotdat(d_crime,'Crime')

# %%
print "hello"
# Out:
# hello

# %%
print plotdata(d_crime, 'Crime')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-abc55fc8a687> in <module>()
# ----> 1 print plotdata(d_crime, 'Crime')
#
# NameError: name 'plotdata' is not defined

# %%
print plotdat(d_crime, 'Crime')
# Out:
# None

# %%
import sys,os
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

# %%
plotdat(d_crime, 'Crime')

# %%
sns.clustermap(t)

# %%
def types_districts(d_crime,per):
    
    # Group by crime type and district 
    hoods_per_type=d_crime.groupby('Crime').Area.value_counts(sort=True)
    t=hoods_per_type.unstack().fillna(0)
    
    # Sort by hood sum
    hood_sum=t.sum(axis=0)
    hood_sum.sort(ascending=False)
    t=t[hood_sum.index]
    
    # Filter by crime per district
    crime_sum=t.sum(axis=1)
    crime_sum.sort()
    
    # Large number, so let's slice the data.
    p=np.percentile(crime_sum,per)
    ix=crime_sum[crime_sum>p]
    t=t.loc[ix.index]
    return t
    
t=types_districts(d_crime,96)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-dc277a71177c> in <module>()
#      20     return t
#      21
# ---> 22 t=types_districts(d_crime,96)
#
# <ipython-input-24-dc277a71177c> in types_districts(d_crime, per)
#       2
#       3     # Group by crime type and district
# ----> 4     hoods_per_type=d_crime.groupby('Crime').Area.value_counts(sort=True)
#       5     t=hoods_per_type.unstack().fillna(0)
#       6
#
# /Users/jmolayem/anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in __getattr__(self, attr)
#     518
#     519         raise AttributeError("%r object has no attribute %r" %
# --> 520                              (type(self).__name__, attr))
#     521
#     522     def __getitem__(self, key):
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'Area'

# %%
cat=d_crime[d_crime['Crime']=='Arson']
c=cat['Crime'].value_counts()
c.sort(ascending=False)
c.head(10)
# Out:
# Series([], dtype: int64)

# %%
cat=d_crime[d_crime['Crime']=='Arson']

# %%
t=types_districts(cat,70)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-4058b5c73828> in <module>()
# ----> 1 t=types_districts(cat,70)
#
# <ipython-input-24-dc277a71177c> in types_districts(d_crime, per)
#       2
#       3     # Group by crime type and district
# ----> 4     hoods_per_type=d_crime.groupby('Crime').Area.value_counts(sort=True)
#       5     t=hoods_per_type.unstack().fillna(0)
#       6
#
# /Users/jmolayem/anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in __getattr__(self, attr)
#     518
#     519         raise AttributeError("%r object has no attribute %r" %
# --> 520                              (type(self).__name__, attr))
#     521
#     522     def __getitem__(self, key):
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'Area'

# %%
cat=d_crime[d_crime['Category']=='DRUG/NARCOTIC']

# Bin crime by 30 day window
cat['Month']=np.floor(cat['days']/30) # Approximate month (30 day window)

# Default
district='All'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-f014945e4d2a> in <module>()
# ----> 1 cat=d_crime[d_crime['Category']=='DRUG/NARCOTIC']
#       2
#       3 # Bin crime by 30 day window
#       4 cat['Month']=np.floor(cat['days']/30) # Approximate month (30 day window)
#       5
#
# /Users/jmolayem/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1795             return self._getitem_multilevel(key)
#    1796         else:
# -> 1797             return self._getitem_column(key)
#    1798
#    1799     def _getitem_column(self, key):
#
# /Users/jmolayem/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1802         # get column
#    1803         if self.columns.is_unique:
# -> 1804             return self._get_item_cache(key)
#    1805
#    1806         # duplicate columns & possible reduce dimensionaility
#
# /Users/jmolayem/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1082         res = cache.get(item)
#    1083         if res is None:
# -> 1084             values = self._data.get(item)
#    1085             res = self._box_item_values(item, values)
#    1086             cache[item] = res
#
# /Users/jmolayem/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    2849
#    2850             if not isnull(item):
# -> 2851                 loc = self.items.get_loc(item)
#    2852             else:
#    2853                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/jmolayem/anaconda/lib/python2.7/site-packages/pandas/core/index.pyc in get_loc(self, key, method)
#    1570         """
#    1571         if method is None:
# -> 1572             return self._engine.get_loc(_values_from_object(key))
#    1573
#    1574         indexer = self.get_indexer([key], method=method)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3824)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3704)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12280)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12231)()
#
# KeyError: 'Category'

# %%
cat=d_crime[d_crime['Crime']=='Arson']

# Bin crime by 30 day window
cat['Month']=np.floor(cat['days']/30) # Approximate month (30 day window)

# Default
district='All'

# %%
def timeseries(dat,per):
    ''' Category grouped by month '''
    
    # Group by crime type and district 
    cat_per_time=dat.groupby('Month').Descript.value_counts(sort=True)
    t=cat_per_time.unstack().fillna(0)
        
    # Filter by crime per district
    crime_sum=t.sum(axis=0)
    crime_sum.sort()
    
    # Large number, so let's slice the data.
    p=np.percentile(crime_sum,per)
    ix=crime_sum[crime_sum>p]
    t=t[ix.index]
    return t
    
t_all=timeseries(cat,0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-499d396444a3> in <module>()
#      16     return t
#      17
# ---> 18 t_all=timeseries(cat,0)
#
# <ipython-input-31-499d396444a3> in timeseries(dat, per)
#       3
#       4     # Group by crime type and district
# ----> 5     cat_per_time=dat.groupby('Month').Descript.value_counts(sort=True)
#       6     t=cat_per_time.unstack().fillna(0)
#       7
#
# /Users/jmolayem/anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in __getattr__(self, attr)
#     518
#     519         raise AttributeError("%r object has no attribute %r" %
# --> 520                              (type(self).__name__, attr))
#     521
#     522     def __getitem__(self, key):
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'Descript'

# %%
def timeseries(dat,per):
    ''' Category grouped by month '''
    
    # Group by crime type and district 
    cat_per_time=dat.groupby('Month').Status.value_counts(sort=True)
    t=cat_per_time.unstack().fillna(0)
        
    # Filter by crime per district
    crime_sum=t.sum(axis=0)
    crime_sum.sort()
    
    # Large number, so let's slice the data.
    p=np.percentile(crime_sum,per)
    ix=crime_sum[crime_sum>p]
    t=t[ix.index]
    return t
    
t_all=timeseries(cat,0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-122b8460553d> in <module>()
#      16     return t
#      17
# ---> 18 t_all=timeseries(cat,0)
#
# <ipython-input-32-122b8460553d> in timeseries(dat, per)
#       4     # Group by crime type and district
#       5     cat_per_time=dat.groupby('Month').Status.value_counts(sort=True)
# ----> 6     t=cat_per_time.unstack().fillna(0)
#       7
#       8     # Filter by crime per district
#
# /Users/jmolayem/anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in unstack(self, level)
#    1955         """
#    1956         from pandas.core.reshape import unstack
# -> 1957         return unstack(self, level)
#    1958
#    1959     #----------------------------------------------------------------------
#
# /Users/jmolayem/anaconda/lib/python2.7/site-packages/pandas/core/reshape.pyc in unstack(obj, level)
#     400             return obj.T.stack(dropna=False)
#     401     else:
# --> 402         unstacker = _Unstacker(obj.values, obj.index, level=level)
#     403         return unstacker.get_result()
#     404
#
# /Users/jmolayem/anaconda/lib/python2.7/site-packages/pandas/core/reshape.pyc in __init__(self, values, index, level, value_columns)
#      87
#      88         # when index includes `nan`, need to lift levels/strides by 1
# ---> 89         self.lift = 1 if -1 in self.index.labels[self.level] else 0
#      90
#      91         self.new_index_levels = list(index.levels)
#
# AttributeError: 'Int64Index' object has no attribute 'labels'
